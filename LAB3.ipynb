# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
from datetime import datetime

data = pd.read_csv('Results_2017-18.csv')

# %%
data
# Out:
#                Timestamp Entering Grade Level  District Birth Month  \
# 0       4/8/2017 6:44:01                    1       6.0   September
# 1      4/7/2017 10:40:45                    K       NaN      August
# 2      4/7/2017 10:41:56                    1       NaN       March
# 3      4/7/2017 10:43:31                    K       NaN   September
# 4     4/10/2017 10:18:34                    K      22.0       April
# ..                   ...                  ...       ...         ...
# 112   6/20/2017 16:06:54                    1       2.0      August
# 113   6/21/2017 22:52:59                    K      20.0        July
# 114   9/14/2017 16:39:55                    K      32.0    February
# 115  11/19/2017 17:07:05                    K       4.0       April
# 116   1/11/2019 15:03:41                    K       2.0     January
#
#     OLSAT Verbal Score OLSAT Verbal Percentile NNAT Non Verbal Raw Score  \
# 0                   28                      99                        45
# ...

# %%
data.describe()
# Out:
#          District  NNAT Non Verbal Percentile  Overall Score
# count  101.000000                  117.000000     117.000000
# mean    12.504950                   98.632479      97.564103
# std     11.406686                    1.393323       2.798967
# min      1.000000                   90.000000      76.000000
# 25%      2.000000                   99.000000      97.000000
# 50%      3.000000                   99.000000      99.000000
# 75%     25.000000                   99.000000      99.000000
# max     32.000000                   99.000000      99.000000

# %%
data.hist(bins=30, figsize=(15, 10))
# Out:
# array([[<AxesSubplot:title={'center':'District'}>,
#         <AxesSubplot:title={'center':'NNAT Non Verbal Percentile'}>],
#        [<AxesSubplot:title={'center':'Overall Score'}>, <AxesSubplot:>]],
#       dtype=object)

# %%
data.loc[data["Entering Grade Level"] == "K", "Entering Grade Level"] = 0
data
# Out:
#                Timestamp Entering Grade Level  District Birth Month  \
# 0       4/8/2017 6:44:01                    1       6.0   September
# 1      4/7/2017 10:40:45                    0       NaN      August
# 2      4/7/2017 10:41:56                    1       NaN       March
# 3      4/7/2017 10:43:31                    0       NaN   September
# 4     4/10/2017 10:18:34                    0      22.0       April
# ..                   ...                  ...       ...         ...
# 112   6/20/2017 16:06:54                    1       2.0      August
# 113   6/21/2017 22:52:59                    0      20.0        July
# 114   9/14/2017 16:39:55                    0      32.0    February
# 115  11/19/2017 17:07:05                    0       4.0       April
# 116   1/11/2019 15:03:41                    0       2.0     January
#
#     OLSAT Verbal Score OLSAT Verbal Percentile NNAT Non Verbal Raw Score  \
# 0                   28                      99                        45
# ...

# %%
data.loc[data["District"].isnull(), "District"] = 0
data
# Out:
#                Timestamp Entering Grade Level  District Birth Month  \
# 0       4/8/2017 6:44:01                    1       6.0   September
# 1      4/7/2017 10:40:45                    0       0.0      August
# 2      4/7/2017 10:41:56                    1       0.0       March
# 3      4/7/2017 10:43:31                    0       0.0   September
# 4     4/10/2017 10:18:34                    0      22.0       April
# ..                   ...                  ...       ...         ...
# 112   6/20/2017 16:06:54                    1       2.0      August
# 113   6/21/2017 22:52:59                    0      20.0        July
# 114   9/14/2017 16:39:55                    0      32.0    February
# 115  11/19/2017 17:07:05                    0       4.0       April
# 116   1/11/2019 15:03:41                    0       2.0     January
#
#     OLSAT Verbal Score OLSAT Verbal Percentile NNAT Non Verbal Raw Score  \
# 0                   28                      99                        45
# ...

# %%
#code to clean up olsat verbal score


for i in range(117):
    if (type(data['OLSAT Verbal Score'][i]) == str):
        try:
            #print("value i is ",i,int(data['OLSAT Verbal Score'][i]))
            data['OLSAT Verbal Score'][i]= int(data['OLSAT Verbal Score'][i])
        except ValueError:
            #print("Oops!  That was no valid number.  Try again...")
            try:
                #print("value i is ",i,int(data['OLSAT Verbal Score'][i][0]+data['OLSAT Verbal Score'][i][1]))
                data['OLSAT Verbal Score'][i]= int(data['OLSAT Verbal Score'][i][0]+data['OLSAT Verbal Score'][i][1].copy(deep=True))
            except Exception as e:
                #print("value i is ",i,0)
                data['OLSAT Verbal Score'][i]=0
                #print("Oops!  That was no valid number.  Try again...")
        #print(int(data['OLSAT Verbal Score'][i]))
data.loc[data["OLSAT Verbal Score"]>30 , "OLSAT Verbal Score"] = 0.3*data['OLSAT Verbal Score']



#change percentages to out of 30
data.loc[data["OLSAT Verbal Score"]>30 , "OLSAT Verbal Score"] = 0.3*data['OLSAT Verbal Score']
print(data['OLSAT Verbal Score'])
    
#histogram of olsat verbal score
plt.hist(data['OLSAT Verbal Score'])
# Out:
# /var/folders/5l/rj_t9bq53g155_h8z8yg700r0000gn/T/ipykernel_32240/3425089217.py:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['OLSAT Verbal Score'][i]= int(data['OLSAT Verbal Score'][i])
# /var/folders/5l/rj_t9bq53g155_h8z8yg700r0000gn/T/ipykernel_32240/3425089217.py:16: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['OLSAT Verbal Score'][i]=0
# 0        28
# 1        25
# 2        27
# 3        23
# 4        25
#        ...
# 112      30
# 113    29.1
# 114      26
# 115      19
# 116      24
# Name: OLSAT Verbal Score, Length: 117, dtype: object
# ...

# %%
#change percentages to out of 30


data.loc[data["OLSAT Verbal Score"]>30 , "OLSAT Verbal Score"] = 0.3*data['OLSAT Verbal Score']

for i in range(117):
    print(data['OLSAT Verbal Score'][i])
    
#histogram of olsat verbal score
plt.hist(data['OLSAT Verbal Score'])
# Out:
# 28
# 25
# 27
# 23
# 25
# 24
# 26
# 24
# 23
# 29
# 17
# 23
# 24
# 29
# 28
# 26
# 26
# 25
# 21
# 25
# 28
# 28
# 28
# 28
# 26
# 28
# 28
# 28
# 26
# 27
# 27
# 9.6
# 19
# 0
# 13
# 29
# 18
# 0
# 18
# 22
# 23
# 0
# 24
# 26
# 26
# 27
# 28
# 24
# 29
# 28
# 29
# 20
# 28
# 25
# 24
# 24
# 24
# 23
# 27
# 22
# 25
# 26
# 26
# 28
# 23
# 29
# 29
# 24
# 29.7
# 25
# 19
# 29
# 27.0
# 20
# 21
# 28
# 30
# 23
# 23
# 21
# 0
# 10.5
# 22
# 28
# 0
# 28
# 0
# 29
# 26
# 23
# 25
# 30
# 30
# 24
# 25
# 25
# 23
# 28
# 24.9
# 26
# 29
# 27
# 29
# 28
# 0
# 24
# 23
# 27
# 0
# 25
# 24
# 29.7
# 30
# 29.099999999999998
# 26
# 19
# 24
# (array([ 8.,  0.,  0.,  2.,  1.,  1.,  7., 17., 37., 44.]),
#  array([0.0, 3.0, 6.0, 9.0, 12.0, 15.0, 18.0, 21.0, 24.0, 27.0, 30.0],
#        dtype=object),
#  <BarContainer object of 10 artists>)

# %%
#code to clean up OLSAT Verbal Percentile
for i in range(117):
    if (type(data['OLSAT Verbal Percentile'][i]) == str):
        try:
            #print("value i is ",i,int(data['OLSAT Verbal Percentile'][i]))
            data['OLSAT Verbal Percentile'][i]= int(data['OLSAT Verbal Percentile'][i])
        except Exception as e:
            data['OLSAT Verbal Percentile'][i]= int(data['OLSAT Verbal Percentile'][i][1]+data['OLSAT Verbal Percentile'][i][2])
            #print("Oops!  That was no valid number.  Try again...")
           
plt.hist(data['OLSAT Verbal Percentile'])
# Out:
# /var/folders/5l/rj_t9bq53g155_h8z8yg700r0000gn/T/ipykernel_32240/1543117777.py:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['OLSAT Verbal Percentile'][i]= int(data['OLSAT Verbal Percentile'][i])
# /var/folders/5l/rj_t9bq53g155_h8z8yg700r0000gn/T/ipykernel_32240/1543117777.py:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['OLSAT Verbal Percentile'][i]= int(data['OLSAT Verbal Percentile'][i][1]+data['OLSAT Verbal Percentile'][i][2])
# (array([ 1.,  0.,  0.,  2.,  0.,  5.,  3., 14.,  3., 89.]),
#  array([55.0, 59.4, 63.8, 68.2, 72.6, 77.0, 81.4, 85.80000000000001, 90.2,
# ...

# %%
#code to clean up NNAT Non Verbal Raw Score

for i in range(117):
    if (type(data['NNAT Non Verbal Raw Score'][i]) == str):
        try:
            #print("value i is ",i,int(data['OLSAT Verbal Score'][i]))
            data['NNAT Non Verbal Raw Score'][i]= int(data['NNAT Non Verbal Raw Score'][i])
        except ValueError:
            #print("Oops!  That was no valid number.  Try again...")
            try:
                #print("value i is ",i,int(data['OLSAT Verbal Score'][i][0]+data['OLSAT Verbal Score'][i][1]))
                data['NNAT Non Verbal Raw Score'][i]= int(data['NNAT Non Verbal Raw Score'][i][0]+data['NNAT Non Verbal Raw Score'][i][1].copy(deep=True))
            except Exception as e:
                #print("value i is ",i,0)
                data['NNAT Non Verbal Raw Score'][i]=0
                #print("Oops!  That was no valid number.  Try again...")
        #print(int(data['OLSAT Verbal Score'][i]))
data.loc[data["NNAT Non Verbal Raw Score"]>48 , "NNAT Non Verbal Raw Score"] = 0.48*data['NNAT Non Verbal Raw Score']



#change percentages to out of 30
data.loc[data["NNAT Non Verbal Raw Score"]>48 , "NNAT Non Verbal Raw Score"] = 0.48*data['NNAT Non Verbal Raw Score']
print(data['NNAT Non Verbal Raw Score'])
    
#histogram of olsat verbal score
plt.hist(data['NNAT Non Verbal Raw Score'])
# Out:
# /var/folders/5l/rj_t9bq53g155_h8z8yg700r0000gn/T/ipykernel_32240/242502859.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['NNAT Non Verbal Raw Score'][i]= int(data['NNAT Non Verbal Raw Score'][i])
# /var/folders/5l/rj_t9bq53g155_h8z8yg700r0000gn/T/ipykernel_32240/242502859.py:15: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['NNAT Non Verbal Raw Score'][i]=0
# 0         45
# 1         39
# 2         42
# 3         40
# 4         38
#        ...
# 112       44
# 113    46.56
# 114       40
# 115       33
# 116       44
# Name: NNAT Non Verbal Raw Score, Length: 117, dtype: object
# ...

# %%
from datetime import datetime
mname = 'March'
mnum = datetime.strptime(mname, '%B').month
#print(mnum, type(mnum))

try:
    for i in range(117):
        data['Birth Month'][i]= datetime.strptime(data['Birth Month'][i], '%B').month
except Exception as e:
    print('error')

data['Birth Month']
# Out:
# /var/folders/5l/rj_t9bq53g155_h8z8yg700r0000gn/T/ipykernel_32240/1758500374.py:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['Birth Month'][i]= datetime.strptime(data['Birth Month'][i], '%B').month
# 0      9
# 1      8
# 2      3
# 3      9
# 4      4
#       ..
# 112    8
# 113    7
# 114    2
# 115    4
# 116    1
# Name: Birth Month, Length: 117, dtype: object

# %%
#turn time stamp into values
try:
    for i in range(117):
        print(i, str(data['Timestamp'][i]))
        data['Timestamp'][i]= int(round(datetime.strptime(str(data['Timestamp'][i]),'%m/%d/%Y %H:%M:%S').timestamp()))
except Exception as e:
    print ("error")

data['Timestamp']
# Out:
# 0 4/8/2017 6:44:01
# 1 4/7/2017 10:40:45
# 2 4/7/2017 10:41:56
# 3 4/7/2017 10:43:31
# 4 4/10/2017 10:18:34
# 5 4/7/2017 11:03:21
# 6 4/7/2017 11:15:28
# 7 4/7/2017 11:26:16
# 8 4/7/2017 11:31:41
# 9 4/7/2017 11:32:52
# 10 4/7/2017 11:57:06
# 11 4/7/2017 12:03:49
# 12 4/7/2017 12:36:07
# 13 4/7/2017 12:42:05
# 14 4/7/2017 13:00:25
# 15 4/7/2017 13:16:38
# 16 4/7/2017 14:50:06
# 17 4/7/2017 16:19:39
# 18 4/8/2017 8:20:44
# 19 4/8/2017 8:33:07
# 20 4/8/2017 8:44:05
# 21 4/8/2017 8:54:04
# 22 4/8/2017 9:26:30
# 23 4/8/2017 9:41:44
# 24 4/8/2017 9:56:57
# 25 4/8/2017 12:34:56
# 26 4/8/2017 16:31:36
# 27 4/8/2017 19:17:06
# 28 4/8/2017 19:56:05
# 29 4/8/2017 22:08:30
# 30 4/9/2017 0:11:05
# 31 4/10/2017 8:30:29
# 32 4/10/2017 9:35:21
# 33 4/10/2017 10:04:50
# 34 4/10/2017 13:25:42
# 35 4/10/2017 20:09:49
# 36 4/11/2017 20:01:30
# 37 4/11/2017 22:32:23
# 38 4/12/2017 12:40:43
# 39 4/12/2017 23:47:39
# 40 4/13/2017 13:10:00
# 41 4/13/2017 14:05:27
# 42 4/13/2017 14:33:37
# ...

# %%
data
# Out:
#       Timestamp Entering Grade Level  District Birth Month OLSAT Verbal Score  \
# 0    1491644641                    1       6.0           9                 28
# 1    1491572445                    0       0.0           8                 25
# 2    1491572516                    1       0.0           3                 27
# 3    1491572611                    0       0.0           9                 23
# 4    1491830314                    0      22.0           4                 25
# ..          ...                  ...       ...         ...                ...
# 112  1497985614                    1       2.0           8                 30
# 113  1498096379                    0      20.0           7               29.1
# 114  1505417995                    0      32.0           2                 26
# 115  1511125625                    0       4.0           4                 19
# 116  1547233421                    0       2.0           1                 24
#
# ...

# %%
data['School Preferences'].where(data['School Preferences'].isnull(), 0)
# Out:
# 0        0
# 1        0
# 2      NaN
# 3      NaN
# 4        0
#       ...
# 112      0
# 113      0
# 114    NaN
# 115      0
# 116      0
# Name: School Preferences, Length: 117, dtype: object

# %%
try:
    for i in range(117):
        if (str(data['Will you enroll there?'][i]).lower() == 'yes' ):
            data['Will you enroll there?'][i]=1
        else:
            data['Will you enroll there?'][i]=0
except Exception as e:
    print('error')
data['Will you enroll there?']
# Out:
# /var/folders/5l/rj_t9bq53g155_h8z8yg700r0000gn/T/ipykernel_32240/1783571904.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['Will you enroll there?'][i]=1
# /var/folders/5l/rj_t9bq53g155_h8z8yg700r0000gn/T/ipykernel_32240/1783571904.py:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['Will you enroll there?'][i]=0
# 0      1
# 1      0
# 2      0
# 3      0
# 4      0
#       ..
# 112    1
# 113    1
# 114    0
# 115    1
# 116    1
# Name: Will you enroll there?, Length: 117, dtype: object

# %%
data
# Out:
#       Timestamp Entering Grade Level  District Birth Month OLSAT Verbal Score  \
# 0    1491644641                    1       6.0           9                 28
# 1    1491572445                    0       0.0           8                 25
# 2    1491572516                    1       0.0           3                 27
# 3    1491572611                    0       0.0           9                 23
# 4    1491830314                    0      22.0           4                 25
# ..          ...                  ...       ...         ...                ...
# 112  1497985614                    1       2.0           8                 30
# 113  1498096379                    0      20.0           7               29.1
# 114  1505417995                    0      32.0           2                 26
# 115  1511125625                    0       4.0           4                 19
# 116  1547233421                    0       2.0           1                 24
#
# ...
